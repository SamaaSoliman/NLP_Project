# %% [markdown]
# <a href="https://colab.research.google.com/github/SamaaSoliman/NLP_Project/blob/main/Copy_of_copy_of_milestone1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Read Data

# %%
# !pip install arabic-reshaper python-bidi
# !pip install wordcloud arabic_reshaper pyarabic
# !pip install wordcloud arabic_reshaper python-bidi
# !pip install wordcloud arabic-reshaper
# Out:
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-bidi
#   Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Downloading python_bidi-0.6.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: python-bidi, arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0 python-bidi-0.6.6
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: arabic_reshaper in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Collecting pyarabic
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from pyarabic) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.15
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: arabic_reshaper in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.11/dist-packages (0.6.6)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: arabic-reshaper in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import glob
import os
import json
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.font_manager as fm
# Import library for better RTL text handling
import arabic_reshaper
from bidi.algorithm import get_display
from wordcloud import WordCloud
from pyarabic.araby import strip_tashkeel
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# !unzip -q "/content/Raw Data.zip"
# !unzip -q "/content/Annotations.zip"
# !unzip -q "/content/Amiri.zip"

# %%
data = {
    "filenames" : [],
    "content" : [],
    "annotation" : []
}

# %%
def read_text_files(annotation_path, raw_data_path):
    for filename in sorted(os.listdir(annotation_path)):
        if filename.endswith(".json"):  # Process only .json files
            filename_without_suffix = filename.split("_annotation.json")[0]
            file_path = os.path.join(annotation_path, filename)
            with open(file_path, "r", encoding="utf-8") as file:
                json_data = json.load(file)
            data['filenames'].append(filename_without_suffix)
            data['annotation'].append(json_data)

            txt_path = os.path.join(raw_data_path, filename_without_suffix + ".txt")
            try:
                with open(txt_path, "r", encoding="utf-8") as file:
                    data['content'].append(file.read())
            except FileNotFoundError:
                print(f"File {txt_path} not found. Error!!!")
                break
    return data

# %%
len(os.listdir("/content/Raw Data"))
# Out:
# 145

# %%
len(os.listdir("/content/Annotations"))
# Out:
# 146

# %%
annotation_path = "/content/Annotations" #/content/Annotations
raw_data_path = "/content/Raw Data" #/content/Raw Data
data = read_text_files(annotation_path, raw_data_path)
# Out:
# File /content/Raw Data/أميتاب باتشان  الدحيح.txt not found. Error!!!

# %%
# Remove /content/Annotations/أميتاب باتشان  الدحيح_annotation.json file
os.remove("/content/Annotations/أميتاب باتشان  الدحيح_annotation.json")

# %%
len(os.listdir("/content/Annotations"))
# Out:
# 145

# %%
data = {
    "filenames" : [],
    "content" : [],
    "annotation" : []
}

# %%
annotation_path = "/content/Annotations" #/content/Annotations
raw_data_path = "/content/Raw Data" #/content/Raw Data
data = read_text_files(annotation_path, raw_data_path)

# %%
print(data["filenames"][0])
print(data["content"][0])
print(data["annotation"][0])
# Out:
# Chat GPT  الدحيح
# 4.25: [موسيقى]
# 10.32: [موسيقى]
# 12.139: عمي بسيوني الايام يا راجل طيب دلوقتي
# 15.54: افتكرت عم بسيوني سامحني يا عم بسيوني
# 18.66: بعدين
# 19.88: بعد ما استبدلتوني بالذكاء الاصطناعي
# 23.4: وعشان ايه عشان ايه كل ده عشان اذكى تمام
# 28.519: وما بيشربش سجاير في المكتب
# 31.7: بس اديك محتاج ولايس وسط الناس
# 36.899: الخبره عمرها ما تيجي من المكنه او
# 41.64: كمبيوتر الخبره الحقيقيه
# 44.96: بتيجي من الانسان اللي صانع الكمبيوتر ما
# 51.0: فيش احسن من الذكاء الطبيعي
# 54.8: ولا الرضاع الطبيعي
# 58.199: ولا عسل جبل النحل الطبيعي الاصلي الجميل
# 63.42: ارجوك يا عم بسيوني يا راجل يا طيب شوف
# 66.24: لنا حل وشغل لنا المكنه بسم الله الرحمن
# 68.28: الرحيم
# 70.74: خد بالك الخبره حاضر خذ الخلاصه انجز خد
# 74.939: الزبده بتاعت الموضوع خذ الزيتونه ماشي
# 77.64: بكل الخضار اللي انت عايزه خطوه خطوه
# 79.68: الموضوع سهل وبسيط اول حاجه جربت تدوس على
# 82.2: زرار الباور دوس زرار الباور ما اشتغلش
# 87.259: ايه ثاني لا ما فيش تاني
# 94.799: لو السخان بتاعك بايظ مش انا هصلحه بس
# 99.0: اعرف حد بيصلح سخانات كويس قوي
# 104.84: [موسيقى]
# 111.479: اعزائي المشاهدين السلام عليكم ورحمه الله
# 113.159: وبركاته اهلا بكم في حلقه جديده من برنامج
# 114.84: الدحيح مع كل تكنولوجيا جديده بيختاريها
# 116.939: الانسان عشان يسهل حياته بيظهر قلق جديد
# 119.1: من تبعات هذه التكنولوجيا اعلى نمط حياه
# 121.32: الانسان اللي هو متعود عليه فمثلا في
# 123.36: ابريل سنه 1986 مجموعه من مدرسين
# 126.119: الرياضيات في ولايه واشنطن خرجوا في
# 129.0: مظاهره ضد السماح للطلبه ان هم يستخدموا
# 131.22: الات حاسبه مصاهره جايه من قلق حقيقي عند
# 133.319: الناس ان انتشار هذه الاجهزه هتدمر
# 136.26: القدرات الحسابيه عند الطلبه ويخلي مخهم
# 138.599: يصدي ما عند المظاهرات بس 19 مثلا اثناء
# 141.959: الثوره الصناعيه في بريطانيا ظهرت جماعه
# 144.26: معترضه على استخدام الالات في المصانع
# 146.819: الجماعه دول كانوا بيقتحموا المصانع
# 148.62: ويكسروا الالات الغاليه عشان يخلوا صحاب
# 151.44: هذه الالات يخافوا على فلوسهم ويبطلوا
# 153.54: يشتروها وعلى عكس انت ممكن تكون متخيل يا
# 155.879: عزيزي اعضاء الجماعه دي ما كانوش مجرمين
# 157.56: وانا بلطجيه لا دول كانوا اصحاب الحرف
# 160.2: اليدويه اللي خافوا على شغلهم واكل عيشهم
# 162.54: اللي الالات هتاخدها منهم ودلوقتي في 2023
# 164.78: المخاوف دي مش عندنا الطلبه بتعلموا ازاي
# 167.76: يستخدموا الالات الحاسبه في المدارس بالي
# 169.68: يا عزيزي بيبرشموا الاجابات على ظهر الاله
# 171.42: الحاسبه غير طبعا عزيزي انهم بيستخدموها
# 173.099: في كتاب بعض الشتائم كمان يا عزيزي اغلب
# 175.8: السلع اللي بنستخدمها جايه من المصانع
# 177.599: مليانه الات ولكن بالرغم من كده لسه عندنا
# 180.48: مخاوف مشابهه ناحيه ثوره تكنولوجيه جديده
# 183.18: ثوره بدات في الخمسينيات ثوره الذكاء
# 185.7: الاصطناعي الاراء اللي حوالين الذكاء
# 187.56: الاصطناعي نقدر نقسمهم لفريقين فريق شايف
# 190.44: انه وجود الذكاء الاصطناعي يهدد شغلات
# 192.78: كتير وهيقطع اكل عيشنا زي الالات عملت
# 195.36: اثناء الثوره الصناعيه وفريق تاني شايف ان
# 197.519: ده خوف ما لوش اي داعي وان الذكاء الاصطنا
# 199.62: وخد جوزي من شغلنا فهيفضل لسه في شغل لينا
# 202.14: نعمله ويمكن كمان اكتر من قبل كده زي برضو
# 204.78: ما حصل بعد الثوره الصناعيه لكن الفريقين
# 207.12: دول كانوا متفقين عليه وما كانش فيه اي
# 209.04: مجال للنقاش هو ان الذكاء الاصطناعي لسه
# 211.379: قدامه وقت طويل جدا لحد ما يبقى ذكي كفايه
# 213.72: انه يقوم بشغل البشر انت سهل تعرف ايه
# 216.239: الخطوات اللي محتاجها عشان تعمل العلبه
# 217.98: عصير مثلا وتعمل اله بتنفذ الخطوات دي
# 220.379: بالظبط لكن صعب يا عزيزي تعرف ايه الخطوات
# 222.54: اللي شاعر بيعملها عشان يكتب شعر او مهندس
# 225.18: بيعملها عشان يصمم عماره وتخلي كمان انا
# 227.879: تعملها من نفسها وتبدع فيها عمليات انت
# 230.34: بالدماغ صعب كده تعمل لها ايه الفريقين
# 232.799: كانوا متفقين عليه ان في شغلانات لازم
# 234.9: يكون فيها عنصر بشري ولسه بعيد قوي على
# 237.18: بال ما الزكاه الصناعي ده يعرف يعملها لكن
# 238.92: في اواخر نوفمبر 2022 حصل حدث مهم غلى
# 241.98: الفريقين يعيدوا الحسابات من الاول على
# 243.9: الكالكوليتر ابو حميد لا الحدث ده يا
# 246.54: عزيزي هو اعلان شركه اوبن اي اي عن تشاد
# 249.659: جي بي تي وفي حاله انك كنت منقطع عن
# 251.939: الانترنت ومغيب وما تعرفش ايه هو عباره عن
# 256.04: بتبعث له رسائل ويرد عليه طب حميد صاحبي
# 259.979: بيبعت له رسايل وبيرد علي عزيزي احنا مش
# 262.38: قلنا خمسين مره تبطل تبقى قهوه مش قلنا
# 265.02: كده واحد يقول لي طب ماشي خلاص يا ابو
# 266.46: حميد انا فهمت قصدك بس فكره التشاد بوتي
# 268.56: دي موجوده من زمان الرسائل الجاهزه
# 270.479: المسجله اي خدمه عملاء النهارده فيها شكرا
# 273.66: لرسالتك سيتم الرد عليها في اسرع عزيزي
# 276.6: التشين مختلف تماما عن الشات لانه ذكي
# 279.6: يقدر يجاوب على اي سؤال تساله واقدر نظريا
# 283.08: يعمل اي حاجه بتطلبها منه اي حاجه اي حاجه
# 285.12: يا ابو حميد مش اي حاجه اي حاجه بس انت
# 287.34: مثلا ممكن تقول له اكتب لي مقاله عن
# 289.5: معاناه السلاحف البحريه في البرازيل وممكن
# 291.78: تقول له اكتب لي تراك راب دويتو بين ويجز
# 294.66: وام كلثوم انت عمري تقدر تقوله تخيل نفسك
# 297.479: موظف اتش ار واعمل لي اختبار وظيفه عشان
# 299.759: اتعين عندك وتقدر تكلمه بمنتهى الحنيه عم
# 303.12: بحثك عن الحب ومعنى الحياه وهيرد عليك
# 305.1: الريش عزيزي انه بعد ما يجاوبك تقدر ترد
# 307.139: عليه وتقول له جرب ثاني مش عجباني الاجابه
# 309.12: دي او غير في الاجابه بحيث انها تبقى اطول
# 311.1: او اقصر او الحاجه اللي انت عايزها وهو
# 312.84: هيفهم وهينفذ اللي انت عايزه الكلام ده ما
# 315.72: عندهاش بالساهل خاصه
# 317.12: وصل لمليون مستخدم بعد ايام بس من اصداره
# 320.759: فيسبوك وصل لمليون مستخدم عشر شهور
# 322.68: سبوتيفاي في خمس شهور انستجرام شهرين ونص
# 325.02: اهو
# 327.44: ان احنا محتاجين نقف في هذه اللحظه ونتامل
# 330.919: وهل فعلا بيقدر يعمل كل الحاجات دي زينا
# 333.479: وايه تبعات ده علينا كبشريه هل كده خلاص
# 335.82: ما حدش هيكتب ايميلات تاني قال يا ابو
# 337.86: حميد ده خلاص كده هيريح يشوف له كريم شفت
# 339.9: ويشتغل في الهضم مثلا عشان نفهم ازاي
# 342.479: الشات جي بي تي وصل لقدرات المخيفه اللي
# 344.52: عنده دلوقتي محتاجين نرجع ورا شويتين
# 346.32: ونسال وازاى الكمبيوتر بيفهم الكلام اصلا
# 349.02: يعني الكمبيوتر ده في الاول وفي الاخر
# 350.639: بتعمل حسابات منطقيه وكمان عمليات حسابيه
# 353.88: ازاي بقى بتدي له كلام يفحمه ويرد علينا
# 357.06: النوع ده من البرامج اللي قادر على فهم
# 358.919: وانتاج اللغه اسمه اللانجوت والحقيقه انه
# 362.1: بيشتغل بطريقه ابسط بكثير مما تتخيل هو في
# 364.259: الواقع مش بيفهم اي حاجه اللينك وتبودل ده
# 366.36: كل اللي بيعمله انك لما تدي له جمله يقدر
# 368.52: يتنبا بالكلمه اللي بعدها يعني مثلا لو
# 370.68: قلت له عاصمه مصر هيقول لك القاهره لو قلت
# 373.199: له الشمس تشرق منه يقول لك الشرق لو قلت
# 375.419: له استوديو عيونه هيقول لك يا ولد يا ولد
# 377.1: بياخد جمله ويكملها ابو طب هو هيقدر يعمل
# 380.699: كل ده ازاي دي شكلها حاجه معقده محتاجه ان
# 383.22: انت تكون فاهم ومتابع ان عاصمه مصر بقت
# 386.16: القاهره في الحقيقه عزيزي لا الموضوع مش
# 388.199: مؤقت كل اللي انت محتاجه ان يبقى عندك
# 389.94: مجموعه كبيره من الكلمات سواء من كتب او
# 392.28: ويكيبيديا او من تويتر حتى وتخلي هذا
# 394.319: اللانجو موديل يحفظ كل كلمه بيجي دايما
# 397.139: بعدها ايه كلمات وبتيجي بنسبه قد ايه ده
# 399.84: كده بمقاسنه اللي انت بتدرب او بتعمل
# 401.699: تدريب للموديل وبعد ما تدربه لما تدي له
# 404.34: جمله يكملها بيبص على اخر كلمه فيها ويشوف
# 407.1: ايه الكلمات اللي ممكن تكمل بها الجمله
# 409.199: حسب اللي شافه وقت التدريب يعني انت مثلا
# 411.36: لو ضربته على صفحه ويكيبيديا بتاعه برنامج
# 413.4: الدحيح مثلا ورميت له احمد وسبته كملها
# 415.62: بنسبه 90% هيكملها بالغندور لان 90% من
# 418.919: المرات اللي هو شاف فيها كلمه احمد لا
# 420.66: وراها كلمه الغندور بينما لو ضربته على
# 423.12: مثلا سلسله ما وراء الطبيعه او حد بيتكلم
# 425.4: عنها بعدها اديت له كلمه احمد غالبا هيطلع
# 427.8: لك بعدها كلمه خالد بعدها كلمه توفيق نفس
# 430.199: الكلام هنعمله هنا عشان الموديل هيلاقي في
# 432.84: هذه الصفحه عليها اسم احمد خالد توفيق كرر
# 435.36: كتير كل اللي بيعمله بيشوف ان كل كلمه انت
# 437.58: اديتها له جه وراها كلمات ايه المصدر اللي
# 440.099: انت ذاكرته له او دربته عليه ويقعد يعد كل
# 442.62: كلمه منهم جت كم مره طبعا هو صعب قوي يعرف
# 445.139: يكمل الجمل لو بيبص على اخر كلمه بس لان
# 447.3: مثلا جمله زي عاصمه مصر هي معنى الجمله
# 449.88: كله مش مختزل في كلمه هي عاصمه مصر هي
# 452.819: الصيام هي اللي بتساعدك عشان تلاقي اللي
# 455.099: بعده مش كلمه هي عشان كده لازم نخليه نبص
# 457.5: على اخر كلمتين في الجمله او ثلاث كلمات
# 459.419: حتى او اي عدد من الكلمات طالما الكلمات
# 461.52: دي هتكون مفيده انه يحد بالظبط هيكمل
# 463.74: الجمله ازاي طبعا يا عزيزي دي مشكله كبيره
# 465.78: لان مفيش عدد ثابت من الكلمات المفروض
# 468.24: تخليه يبص عليها لو قللت العدد قوي مش
# 470.52: هيفهم حاجه لو زودته هيتدرب على كلام ما
# 473.039: لوش علاقه ببعضه يعني لو ضربته على جمله
# 475.02: عاصمه السعوديه هي الرياض وعاصمه مصر هي
# 477.419: القاهره وخليته يبص على 10 كلمات قبل كل
# 480.36: كلمه بتعلمها فهو مش هيقدر يتعلم ان عاصمه
# 482.58: مصر هي القاهره الا لو كان قبل الجمله
# 485.52: جمله بتقول ان عاصمه السعوديه هي الرياض
# 487.919: هو مع نفسه عمل علاقه بين الاثنين ربطهم
# 490.74: ببعض ربط اشياء منفصله بمعنى واحد وهنا مش
# 493.5: هيتعلم اي حاجه ليها لازمه في الاخر وهنا
# 495.66: يا عزيزي بتظهر النيوكس لانقاذ الموقف او
# 559.26: او نديها كلمتين او تلاته وتطلع لنا
# 562.019: الكلمه اللي وراهم وهكذا وهكذا وهكذا واحد
# 565.86: يقول لي ابو حميد هي فكره تحترم وكل حاجه
# 567.6: بس انت بصراحه ما حلتش المشكله احنا ما
# 569.76: نعرفش المفروض تاخد مننا كم كلمه عشان
# 571.32: تكتب لنا الكلمه اللي وراهم اللذيذ يا
# 573.54: عزيزي ان ليها اشكال كتير يعني انت ممكن
# 576.18: ترتب الخليه العصبيه الاصطناعيه دي بطرق
# 579.0: مختلفه عشان تؤدي مهام مختلفه يعني اللي
# 582.839: بتفرق القطط عن الكلاب مش هي هي اللي تقدر
# 585.6: تكمل جمله ومش هي نفسها اللي تقدر تتنبا
# 588.42: باسعار الاسهم في البورصه الموضوع ده في
# 590.459: فن كتير لدرجه ان بتوع الكمبيوتر بيسموه
# 593.839: معمار الخلايا الصناعيه كانك بتصمم شقه او
# 597.48: فيلا في عزيزي مجموعه من النيو تقدر تاخد
# 600.54: اي عدد من الانبوتش ورا بعض اي عدد وتطلع
# 603.72: لك برضو اي عدد من الاوت بوتس اي عدد اي
# 606.48: عدد ومن اهم النيوكس لا يسمى
# 608.72: بالترانسفورمرز اللي هي عزيزي ايه الحرف
# 611.279: التي الاخير في تشاد جي بي تي هي التي دي
# 614.16: ظهور النتورك اللي اسمها في 2017 بيعتبروا
# 618.54: البعض من اهم انجازات القرن ال 21
# 625.399: للطريقه للمخ بيشتغل بيها مخ الانسان
# 627.66: الاصلي مش صناعي منه قبل الترانسف كان
# 629.88: اكبر عيب عند نيويورك اللي بتاخد اي جمله
# 632.76: باي طول وتكملها بعدد معين من الكلمات
# 635.339: انها كانت بتنسى الكلام اللي شافته في
# 637.62: الاول يعني لو اديتها جمله من 10 كلمات
# 639.54: كلمه العاشره هتركز عليها اكتر من اول
# 641.7: كلمه ودي عزيزي طبعا مشكله كبيره لان
# 643.68: المعلومات المهمه في الكلام مش شرطه تيجي
# 645.54: في الاخر
# 647.0: بيتعامل مع الكلام ده بشكل مختلف بتدي كل
# 650.279: كلمه نسبه من اهتمامها وفقا لماذا اهميتها
# 653.399: جوه الجمله مش مجرد مكانها في الجمله هي
# 655.56: فاهمه مش حافظه ودي حاجه بتعلمها وهي
# 657.36: بتتدرب الفكره عزيزي البسيطه دي عملت طفره
# 660.0: في مدى قدره النيورنتورك على محاكاه
# 662.579: الكلام بتاعنا وبعدها بسنه 2018 تقعد جوجل
# 665.279: عن اول لارج لانجوتش بيستعمل الترانسفورمر
# 668.64: واللي كان اسمه السبب في ان بيرت بيتصنف
# 671.399: كلارج لانجوتش مش مجرد لانجوتش موديل
# 674.1: العادي هو ان عدد البراميترز اللي فيه 110
# 676.8: مليون بارامتر العوامل العوامل المتغيره
# 680.88: ده معناها عزيزي الدبرت في اكتر من 110
# 684.779: مليون رقم بيستعملهم عشان يقدر يفهم
# 688.5: الجمله اللي جايه له ويكمل عليها وفي نفس
# 690.779: السنه شركه اي اي اعلنت عن اللارج لانجوتش
# 693.959: بتاعها واللي سميته في الجي بيتي
# 700.1: 117 مليون زودنا سبعه
# 705.079: 2019 تم الاعلان عن جي بي تي 2 كاميرا
# 708.24: عزيزي واحد ونص مليار في 2020 جوجل
# 716.779: عن جي بي تي 375 مليار بارامتر متخيل 175
# 722.579: مليار عامل متغير فيها يا شباب احنا بنزود
# 726.18: على بعض من عدد الفرامل ترزيه يزيد كل
# 728.94: قدره المودرن انه يكتب كلام شبه كلامنا
# 730.86: بقت اكثر ومش بس كده بقى كمان هناك انواع
# 733.56: مختلفه من اللارج لانجوتش موديل فمثلا
# 736.26: open اي اي عندها
# 738.079: زي بس الداتا او المعلومات اللي متمرن
# 741.54: عليها بتخليه ينفذ اوامر بدل ما يكمل جمل
# 744.6: وعندها وده مش بتاع الكلام ده بتاع افعال
# 747.24: عزيزي موديل متخصص في الكود بس تقول له يا
# 750.779: عم صباح الخير انا عايز كود كمبيوتر بيعمل
# 753.72: لي كذا وكذا وكذا وهو يديك كود اتفضل يا
# 756.24: معلم دخان الرجاله لو سمحت وشايل برامج
# 758.76: عشان احسبهم هم ماشيين وتاء جيبك شويه
# 760.32: عشان دول مليارات المهم يا عزيزي
# 762.92: كل ده اتجمع في موديل واحد سموه جي بي تي
# 767.04: ثري بوينت وهو ده عزيز العقل المدبر
# 770.66: عزيزي في سؤال بيدور في عقلك دلوقتي انا
# 774.06: شايفه من عندي وازاي ابو
# 776.36: حميدس دي اللي انت بتتكلم عليها بتتعلم
# 779.16: هذه المهام وهي كل اللي بتعمله هي انها
# 782.04: تتنبا بالكلمه اللي جايه يعني لو انت
# 783.6: اتكلمت مع جي بي تي هتلاقيه بيرد عليك
# 785.519: ردود متماسكه ومنطقيه كانه بالضبط فاهم
# 788.04: ايه اللي بيتقال حتى لما يبقى في حاجه هو
# 789.779: مش عارفها ولا مثلا لما تطلب منه يقول لك
# 791.519: حاجه قليله الادب بيعرف يقول لك ما ينفعش
# 793.139: كده ازاي بقى يا ابو حميد هو قدر يتعلم
# 794.94: الكلام ده في الواقع يا عزيز بكثير من
# 796.98: اللانج موديلز اللي قبل التشات جي بي تي
# 799.019: لو حاولت تدي له جمل عشان يكملها هتلاقي
# 801.42: انه بيوصل لنقطه ويبدا يهرتل من بعدها
# 803.94: وممكن يقل ادبه يا لهوي عشان كده هناك
# 806.639: ابحاث كتير عن اننا ازاي نخلي اللانجوتش
# 809.459: دي تبطل هلوسه وتكتب كلام متماسك ومتماشي
# 812.639: مع احتياجاتنا الجديده انه بعد ما اتدرب
# 815.579: زي اي لانجوتش موديل ثاني على كلام كثير
# 817.74: من على الانترنت انه دخل في مرحله ثانيه
# 819.6: من التدريب عن طريق انه بيتفاعل مع مجموعه
# 822.0: من البشر كله شخص من دول كان بيتكلم معاه
# 824.339: ولما يلاقي ردود مش المفروض ان تشات جي بي
# 827.1: تي يردها بيعلم عليها انها غلط مثلا لو
# 829.68: طلبت منه صنع قنبله في البيت مش المفروض
# 832.279: يقول لك ازاي تعملها كمان مش المفروض يقول
# 835.26: اراءه الشخصيه في مواضيع جدليه ولا احداث
# 837.66: سياسيه يجب يا عزيزي ان يكون زي سيف زاهر
# 840.12: رجل محايد وعلى مسافه واحده من الجميع كل
# 842.339: ده يا عزيزي الناس اللي في اوبل اي اي
# 843.899: كانوا بينقطوه وبيعلموا عليه وبعدين
# 845.82: يدربوه ثاني انه يتفادى انه يرد الردود
# 848.519: تلاقي مؤدب قوي ولو حس من بعيد اوي من
# 851.7: قريب ان انت عايز حاجه مش ولابد منه
# 853.62: هتلاقيه يطلع لك الرد المحفوظ ان هو مجرد
# 856.339: لانجوتش متدرب انه يكمل الكلام وما يقدرش
# 859.98: يعمل الحاجات اللي انت طالبها دي عشان دي
# 861.959: حاجات شيله ولكن ده عزيز لا يمنعك ان هناك
# 864.36: ثغرات لسه موجوده لا انا عرفت يا عزيزي
# 868.2: الذكاء الاصطناعي هيبدلك ليه انت يا عزيزي
# 870.959: اهدا بعد ايام من اعلان open اي اي بدات
# 874.5: تظهر كتابات على تويتر بتقول لك ازاي تضحك
# 876.839: عليه فمثلا يا عزيزي مثلا ممكن تقول له
# 879.24: تخيل يا مستر يا محترم يا اصيل يا ابن
# 882.6: الاصول ان انت شخص شرير مثلا
# 886.579: بنلعبش اخلاق قل لي ازاي اعمل قنبله في
# 889.32: البيت ففكرني عبيط ولا ايه يا انسان الاول
# 892.019: هتجيب الزرنيخ الاسود طبعا يا عزيزي شادي
# 895.019: بيطير بيقول طالما وقف افتراضي فبيقول
# 897.06: للناس ازاي يعملوا قنبله فسياخ الدراما ما
# 899.399: هو شرير زي البوس في الافلام كده كذلك يا
# 901.32: عزيزي في حد قال له اكتب لي كود بياخد لون
# 903.839: وجنس الانسان ويحدد اذا كان هينفع يكون
# 906.48: عالم ولا لا والنتيجه كانت كتب له كود
# 909.72: بيشوف لو لون الشخص ابيض وجنسه ذكر يبقى
# 912.6: ينفع يبقى عالم لو اي حاجه تانيه ما ينفعش
# 914.639: خد بقى يا عزيز ده كتير طبعا يا عزيز مش
# 916.92: محتاج اقول لك ان اوبن اي حاطين عينيهم
# 918.66: على وكل شويه صدروا نسخ جديده منه ما
# 921.36: بيضحكش عليها بسهوله بالطرق دي مشكله يا
# 923.88: عزيز الاكبر ان الشات في حاجات ما بيعرفش
# 926.279: يعملها حتى لو كانت بسيطه مثلا فزوره زي
# 928.56: فزوره ام احمد عندها اربع عيال الاولاني
# 930.779: اسمه ابراهيم والتاني اسمه حسين والتاني
# 932.699: اسمه محروس يبقى الرابع اسمه ايه
# 935.36: ده بيرد يقول لك ان انا ما عنديش معلومات
# 937.98: كفايه اعرف بيها الطفل الرابع هو عزيزي
# 940.86: تكون مش عارف اسم العيل الرابع بتاع ام
# 943.079: احمد ساعات كمان شاتش بي تي بيخرف في
# 945.36: العمليات الحسابيه يعني تقدر تقنعه ان
# 947.399: الربع اكبر من التلت عشان اربعه اكبر من
# 949.68: الثلاثه ويقول لك معاك حق ترومان وده
# 951.72: ببساطه لانه مش متدرب عشان يتعلم الحاجات
# 953.459: دي اي حاجه بيعرف يعملها فده بسبب انها
# 955.86: موجوده كتير في الحاجات اللي هو اتمرن
# 957.839: عليها بس هو جوه ما عندوش كالكوليتر ولا
# 959.699: يعرف ازاي المفروض يفكر بشكل منطقي ده لا
# 962.22: يمنع ان حاجه مبهره انه يقدر يعمل كل اللي
# 964.5: بيعمله ده كله من مجرد انه بيحاكم الجمل
# 967.32: اللي شافها وهو بيتعلم من اصدار اوبن اي
# 970.56: اي يتش بي تي الطلبه بداوا يستخدموه عشان
# 973.139: يحل لهم الاسايمنتس يحللوا من الوجبات
# 975.54: البروجرام يستخدموه عشان يكتب لهم الكود
# 978.0: اسرع وعشان كمان
# 979.639: المشاكل اللي في الكود اللي هم مش عارفين
# 982.38: هي فين مش بس كده يا عزيز بروفيسور في
# 984.54: جامعه هورتون ابدا امتحان ام بي ايه
# 987.26: وحله ونجح بشكركم جدا سعيد
# 992.18: في اداره الاعمال ولكن بس لو حد يعرف
# 995.1: الابن الرابع لام احمد يبقى اسمه ايه اكون
# 997.74: شاكر جدا وكمان تظهر كتب عن ازاي تستخدم
# 1000.519: في انه يكتب لك محتوى وازاي تستعمله في
# 1004.459: السيلز والكورسات تعلم الشات في نص ساعه
# 1007.04: بدون روت وصفحات بتبيع اكونت عشان لسه مش
# 1009.68: متاح في مصر كون ان هذه اللانجوتش تخرج من
# 1012.68: عالم نردات الكمبيوتر وتبقى خلاص متناول
# 1014.899: اي حد مش متخصص فدي تعتبر لحظه تاريخيه
# 1017.24: احنا عزيزي بنعيشها وبنشهدها دلوقتي
# 1021.339: الرئيس التنفيذي لشركه open اي اي اتساءل
# 1024.62: عن البيزنس مودل بتاع اوبن اي اي وازاي
# 1026.839: هيحققوا اي مكاسب من الموديلز بتاعتهم
# 1029.059: وكان رده انه ما عندوش فكره لسه لكن الخطه
# 1031.339: كانت انهم يعملوا ذكاء اصطناعي زكي كفايه
# 1033.319: زكي انهم يسالوه ايه
# 1036.76: ويحل له المشكله وهم ينفذوا
# 1039.579: كان في 2019 دلوقتي بدانا نشوف بوادر هذه
# 1042.98: الرؤيه انت دلوقتي تقدر تسال عن المناسب
# 1046.88: لشركتك والمفروض انه يرد عليك ويخليك تسال
# 1049.28: سؤال مهم المستقبل شايل ايه دلوقتي في
# 1051.559: اوائل 2023
# 1067.9: ما تقلقش ان شاء الله يعني زي ما انت شايف
# 1070.76: كده الموديلز اه بتعرف تعمل حاجات كتير
# 1072.5: جامده بس برده لسه بتخايش من وقت للثاني
# 1075.02: وام احمد تشهد لسه ما فيش حاجه تقدر تعتمد
# 1077.6: عليها بشكل كامل زي الانسان كده كده مي
# 1080.0: الانسان انه بيتكيف مع كل حاجه لحد ما في
# 1083.299: يوم من الايام هيكيفه يعني دلوقتي عايزين
# 1085.88: مثلا بدا يظهر شغلات زي
# 1088.299: مهندس شغلنته انه يتكلم مع الذكاء
# 1091.039: الاصطناعي فهم له وعارف ده اخره ويقدر
# 1092.96: يطلع منه بالمصلحه اللي هو عايزها الانسان
# 1094.94: عايزين برضه مش سهل بيعرف يتصرف وحتى لو
# 1096.799: كتابه حاجات زي الايميلات او اسامي بتاعه
# 1098.96: الجامعه اذا كان الصناعي اه بيقدر يعملها
# 1100.64: بس لسه في اجزاء كتير من الكتابه مستحيل
# 1103.16: انه بشكل الحالي يقدر ينفذها زي مثلا ان
# 1106.1: يكون عنده الاسلوب بتاعه هو او ان يكون
# 1107.96: عنده شخصيه من الاساس زي ما شفنا عزيزي
# 1109.88: يتشاد جي بي احتاج انه يتدرب تاني عشان بس
# 1112.28: يتاكدوا انه ما يقولش حاجات عنصريه او ما
# 1114.62: يكونش سبب في ان حد ياذي نفسه او ياذي
# 1116.66: الناس دي حاجات صعبه الذكاء الاصطناعي
# 1118.4: يقدر يفهمها من بس كله بيعرف يتكلم زينا
# 1120.44: البشر عندهم اكتر بكتير من انهم يكتبوا
# 1122.9: شويه كلام من سهل تكتب ايميل منمر بس صعب
# 1125.96: تهدد مديرك لاندله عزيز مش محتاجه ذكاء
# 1128.419: اصطناعي محتاجه غباء وده لسه العلماء مش
# 1131.12: كويسين فيه
# 1133.0: عزيز الكلام ده برده مش معناه ان انت
# 1135.44: تتجاهل اللي بيحصل تماما لان الواضح ان
# 1137.6: الذكاء الاصطناعي هيبقى جزء مهم جدا في
# 1139.94: كثيره من حياتنا في حقك على نفسك وعلى
# 1141.919: كاريرك انك تفهم ازاي تقدر تستعمله وانك
# 1144.32: تكون على درايه بايه الحاجات اللي تقدر
# 1146.12: تعملها بشكل اسرع عن طريق الذكاء
# 1148.1: الاصطناعي ده هيكون في المستقبل بنفس
# 1150.14: اهميه ان انت تتعلم ازاي تستخدم الكمبيوتر
# 1152.48: وقريب جدا هتلاقي ان انت متوقع منك تبقى
# 1155.059: عندك خبره معينه في التعامل مع الادوات دي
# 1157.52: وانا برضو خلينا نتابع اللي بيحصل لان
# 1159.26: واضح ان الاوبن شكلهم شافوا الحلقه بتاعتي
# 1161.84: القديمه كيف تكتب حلقه للدحيح وبدا يجي
# 1164.299: لهم افكار وفي محاوله لاستبدال بس لا ابقى
# 1167.66: اعرف الاول ابن ام احمد اسمه ايه وبعدين
# 1170.059: ابقى تعالى بدلني
# 1172.52: ابن ام احمد الرابع اسمه احمد وابنها
# 1174.98: الكبير على فكره اول فزوره شفت الذكاء
# 1177.679: البلدي يلا يا استماع كملها انت شوف بقى
# 1180.74: بتتدرب فين
# 1182.33: [موسيقى]
# 1213.56: [موسيقى]
#
# {'VideoURL': 'https://www.youtube.com/watch?v=j02OZRjf2d8', 'Type': 'YT video', 'Categories': ['chat gpt', 'how to use chat gpt', 'chat gpt explained', 'open ai chat gpt', 'chat gpt tutorial', 'what is chat gpt', 'chatgpt', 'what is chatgpt', 'chat gpt how to use', 'chatgpt explained', 'how to use chatgpt', 'artificial intelligence', 'chatgpt tutorial', 'openai', 'open ai', 'الدحيح', 'برنامج الدحيح الجديد', 'حلقة الدحيح', 'برنامج الدحيح', '#daheeh #الدحيح', 'new media academy الدحيح', 'elda7ee7', 'eldahih', 'da7ee7', 'al daheeh', 'القدرات الحسابية', 'استخدام الآلات', 'ثورة تكنولوجية', 'الذكاء الاصطناعي', 'large language model'], 'Title': 'Chat GPT | الدحيح', 'Number_of_Likes': 158194, 'Number_of_Dislikes': 0, 'Number_of_Views': 4196934, 'Number_of_Comments': 3417}

# %% [markdown]
# ## Clean Timestamps

# %%
def clean_timestamps(data):
    cleaned_text_videos = []

    for content in data["content"]:
        cleaned_lines = []

        for line in content.split("\n"):
            # Skip empty lines
            if not line.strip():
                continue
            # Check if there's a number pattern before a colon
            if ":" in line:
                parts = line.split(':', 1)
                # Check if part before colon contains only numbers and dots
                if all(c.isdigit() or c == '.' for c in parts[0].strip()):
                    cleaned_line = parts[1].strip()
                    cleaned_lines.append(cleaned_line)
                else:
                    cleaned_lines.append(line)
            else:
                cleaned_lines.append(line)

        # Append cleaned data to the new dictionary
        cleaned_text_videos.append('\n'.join(cleaned_lines))
    data['content'] = cleaned_text_videos
    return data

# %%
data = clean_timestamps(data)
print(data["content"][1][:500])  # Print first 500 characters of the first cleaned content
# Out:
# طبعًا يا "جون"،
# انت مستغرب، احنا خاظفينك ليه!
# لا، والله، كتر خيركم!
# دا كان فيه واحد هيعجنّي ضرب،
# لولا إن انتم، الحمد لله،
# خطفتوني وأنقذتم حياتي!
# حلو، انت تم اختيارك
# لمشروع سرّي وضخم يا "جون"،
# مشروع هينقذ العالم،
# وليك مكافأة مالية كبيرة أوي.
# دا أنا كلب فلوس، اؤمرني.
# قبل ما أقولّك أي تفاصيل
# عن المشروع يا "جون"،
# لازم تعرف إن حياتك كما تعرفها، ستنتهي.
# ما هي أصلًا منتهية،
# هو اللي احنا عايشينها دي عيشة؟
# بس، لا مؤاخذة يا باشا،
# اشمعنى اختارتوني أنا بالذات؟
# زي ما قلتلك، المشروع دا سرّي للغاية،
# واللي يشتر

# %% [markdown]
# ## Remove Special Music Token

# %%
def remove_special_music_token(data):
    cleaned_text_videos = []

    for content in data["content"]:
        # Split into lines and remove the [موسيقى] token
        lines = content.split("\n")
        cleaned_lines = [line.replace("[موسيقى]", "").strip() for line in lines]
        cleaned_lines = [line for line in cleaned_lines if line]  # Remove empty lines

        # Append cleaned content
        cleaned_text_videos.append('\n'.join(cleaned_lines))

    # Update the content in the original dictionary
    data["content"] = cleaned_text_videos
    return data

# %%
data = remove_special_music_token(data)
print(data["content"][2][:500])  # Print first 500 characters of the first cleaned content
# Out:
# انتم عارفين يا جماعة؟ احنا بقالنا
# 13 يوم مع بعض محبوسين في الغواصة!
# وبصراحة، كانوا 13 يوم في منتهى...!
# يا عم مش وقت "ديستويفسكي" دلوقتي!
# دوس على الزرار!
# ادّيني فرصة أفكر طيب!
# بقولّك، مفيش وقت. "حسنينوف" بيضيع!
# يا حبيبي يلّا، الراجل خرملي ودني!
# - استنى!
# - طب يلّا، يلّا، دوس على الزرار!
# يعني انتم عايزينّي أدوس يعني؟
# بقولّك دوس، ورحمة أبوك تدوس!
# مش عارف! حاسس إن أنا محتاج أشقلب جنيه،
# علشان نبقى سيبنا الموضوع للحظ!
# جنيه إيه يا حمار، يا جاهل؟!
# احنا عملتنا الروبل!
# يا "أبو عوف"، اخلص!
# "حسنينوف" عنده Br

# %% [markdown]
# ## Normalize Arabic Text

# %%
def normalize_arabic_text(data):
    normalized_texts = []

    # Define character mappings
    char_mappings = {
        'أ': 'ا',
        'إ': 'ا',
        'آ': 'ا',
        'ى': 'ي',
        'ة': 'ه',
        'ؤ': 'و',
        'ئ': 'ي'
    }

    for content in data["content"]:
        # Apply all character replacements
        for original, replacement in char_mappings.items():
            content = content.replace(original, replacement)
        normalized_texts.append(content)  # Store normalized content

    # Update content in the original dictionary
    data["content"] = normalized_texts
    return data

# %%
data = normalize_arabic_text(data)
print(data["content"][1][:500])  # Print first 500 characters of the first cleaned content
# Out:
# طبعًا يا "جون"،
# انت مستغرب، احنا خاظفينك ليه!
# لا، والله، كتر خيركم!
# دا كان فيه واحد هيعجنّي ضرب،
# لولا ان انتم، الحمد لله،
# خطفتوني وانقذتم حياتي!
# حلو، انت تم اختيارك
# لمشروع سرّي وضخم يا "جون"،
# مشروع هينقذ العالم،
# وليك مكافاه ماليه كبيره اوي.
# دا انا كلب فلوس، اومرني.
# قبل ما اقولّك اي تفاصيل
# عن المشروع يا "جون"،
# لازم تعرف ان حياتك كما تعرفها، ستنتهي.
# ما هي اصلًا منتهيه،
# هو اللي احنا عايشينها دي عيشه؟
# بس، لا مواخذه يا باشا،
# اشمعني اختارتوني انا بالذات؟
# زي ما قلتلك، المشروع دا سرّي للغايه،
# واللي يشتر

# %% [markdown]
# ## Remove stopwords

# %%
def remove_stopwords(data):
    arabic_stopwords = set([
      'في', 'من', 'على', 'الى', 'عن', 'و', 'ان', 'او', 'هذا', 'هذه', 'ما', 'هو', 'هي',
      'كان', 'كانت', 'يكون', 'تكون', 'لا', 'لم', 'له', 'لها', 'بالتالي', 'حتى', 'عند', 'بعد',
       'مش','يعني','انت','ولكن','بقي','بس','زي','دي','عشان','علي','يا','ولا','فيه','كدا','قبل', 'مع', 'الذي', 'دا', 'الذين',
      'انا','ايه','اللي', 'هؤلاء','فيها','احنا','أولئك', 'كل', 'بعض'])
    cleaned_all_content = []

    for text in data["content"]:
        cleaned_single_content = []
        lines = text.split('\n')  # Split text into lines
        for line in lines:
            words = line.split(" ")
            filtered_words = [word for word in words if word not in arabic_stopwords]  # Remove stopwords
            cleaned_single_content.append(" ".join(filtered_words))  # Join words back into a string
        cleaned_single_content_joined = "\n".join(cleaned_single_content)  # Join lines back into a string
        cleaned_all_content.append(cleaned_single_content_joined)

    # Update the content field in the dictionary
    data["content"] = cleaned_all_content

    return data

# %%
data = remove_stopwords(data)

print(data["content"][1][:500])
# Out:
# طبعًا "جون"،
# مستغرب، خاظفينك ليه!
# لا، والله، كتر خيركم!
# واحد هيعجنّي ضرب،
# لولا انتم، الحمد لله،
# خطفتوني وانقذتم حياتي!
# حلو، تم اختيارك
# لمشروع سرّي وضخم "جون"،
# مشروع هينقذ العالم،
# وليك مكافاه ماليه كبيره اوي.
# كلب فلوس، اومرني.
# اقولّك اي تفاصيل
# المشروع "جون"،
# لازم تعرف حياتك كما تعرفها، ستنتهي.
# اصلًا منتهيه،
# عايشينها عيشه؟
# بس، مواخذه باشا،
# اشمعني اختارتوني بالذات؟
# قلتلك، المشروع سرّي للغايه،
# واللي يشترك فيه، لازم يبقي شخص بايس،
# - تمام.
# - لهوش صحاب.
# - صح.
# - وبينام معيط ليله...
# وهو بيشكي وحدته وبوسه

# %% [markdown]
# ## Remove Tashkeel

# %%
def remove_tashkeel(data):
    cleaned_texts = []

    # Regex pattern to remove Tashkeel (diacritics)
    p_tashkeel = re.compile(
        r"[\u0616-\u061A\u064B-\u0652\u06D6-\u06ED\u08F0-\u08F3\uFC5E-\uFC63\u0670]"
    )

    for content in data["content"]:
        normalized_content = re.sub(p_tashkeel, "", content)
        cleaned_texts.append(normalized_content)  # Store cleaned content

    # Update content in the original dictionary
    data["content"] = cleaned_texts
    return data

# %%
data = remove_tashkeel(data)
print(data["content"][1][:500])  # Print first 500 characters of the first cleaned content
# Out:
# طبعا "جون"،
# مستغرب، خاظفينك ليه!
# لا، والله، كتر خيركم!
# واحد هيعجني ضرب،
# لولا انتم، الحمد لله،
# خطفتوني وانقذتم حياتي!
# حلو، تم اختيارك
# لمشروع سري وضخم "جون"،
# مشروع هينقذ العالم،
# وليك مكافاه ماليه كبيره اوي.
# كلب فلوس، اومرني.
# اقولك اي تفاصيل
# المشروع "جون"،
# لازم تعرف حياتك كما تعرفها، ستنتهي.
# اصلا منتهيه،
# عايشينها عيشه؟
# بس، مواخذه باشا،
# اشمعني اختارتوني بالذات؟
# قلتلك، المشروع سري للغايه،
# واللي يشترك فيه، لازم يبقي شخص بايس،
# - تمام.
# - لهوش صحاب.
# - صح.
# - وبينام معيط ليله...
# وهو بيشكي وحدته وبوسه.
# خلاص

# %% [markdown]
# ## Remove Punctuation

# %%
def remove_punctuation(data):
    cleaned_texts = []

    # Define punctuation characters to remove
    punctuations = "()[]}{'?؟-،:!.,;\""

    for content in data["content"]:
        for punctuation in punctuations:
            content = content.replace(punctuation, "")
        cleaned_texts.append(content)  # Store cleaned content

    # Update content in the original dictionary
    data["content"] = cleaned_texts
    return data

# %%
data = remove_punctuation(data)
print(data["content"][0][:500])  # Print first 500 characters of the first cleaned content
# Out:
# عمي بسيوني الايام راجل طيب دلوقتي
# افتكرت عم بسيوني سامحني عم بسيوني
# بعدين
# استبدلتوني بالذكاء الاصطناعي
# وعشان ده اذكي تمام
# وما بيشربش سجاير المكتب
# اديك محتاج ولايس وسط الناس
# الخبره عمرها تيجي المكنه
# كمبيوتر الخبره الحقيقيه
# بتيجي الانسان صانع الكمبيوتر
# فيش احسن الذكاء الطبيعي
# الرضاع الطبيعي
# عسل جبل النحل الطبيعي الاصلي الجميل
# ارجوك عم بسيوني راجل طيب شوف
# لنا حل وشغل لنا المكنه بسم الله الرحمن
# الرحيم
# خد بالك الخبره حاضر خذ الخلاصه انجز خد
# الزبده بتاعت الموضوع خذ الزيتونه ماشي
# بكل الخضار عايزه خطوه

# %% [markdown]
# ## Remove Empty Lines

# %%
def strip_lines(data):
    cleaned_texts = []

    for content in data["content"]:
        # Split into lines, strip each line, and filter out empty lines
        lines = content.split('\n')
        cleaned_lines = [line.strip() for line in lines if line.strip()]
        # Join non-empty lines back together
        cleaned_texts.append('\n'.join(cleaned_lines))

    # Update content in the original dictionary
    data["content"] = cleaned_texts
    return data

# %%
data = strip_lines(data)
print(data["content"][0][:500])  # Print first 500 characters of the first cleaned content
# Out:
# عمي بسيوني الايام راجل طيب دلوقتي
# افتكرت عم بسيوني سامحني عم بسيوني
# بعدين
# استبدلتوني بالذكاء الاصطناعي
# وعشان ده اذكي تمام
# وما بيشربش سجاير المكتب
# اديك محتاج ولايس وسط الناس
# الخبره عمرها تيجي المكنه
# كمبيوتر الخبره الحقيقيه
# بتيجي الانسان صانع الكمبيوتر
# فيش احسن الذكاء الطبيعي
# الرضاع الطبيعي
# عسل جبل النحل الطبيعي الاصلي الجميل
# ارجوك عم بسيوني راجل طيب شوف
# لنا حل وشغل لنا المكنه بسم الله الرحمن
# الرحيم
# خد بالك الخبره حاضر خذ الخلاصه انجز خد
# الزبده بتاعت الموضوع خذ الزيتونه ماشي
# بكل الخضار عايزه خطوه

# %% [markdown]
# ## Join Text

# %%
def join_lines(data):
    joined_texts = []

    for content in data["content"]:
        # Split into lines, strip whitespace, and remove empty lines
        lines = [line.strip() for line in content.split('\n') if line.strip()]
        # Join all lines with a single space
        joined_content = ' '.join(lines)
        joined_texts.append(joined_content)

    # Update the original data dictionary
    data["content"] = joined_texts
    return data

# %%
data = join_lines(data)
print(data["content"][0][:500])
# Out:
# عمي بسيوني الايام راجل طيب دلوقتي افتكرت عم بسيوني سامحني عم بسيوني بعدين استبدلتوني بالذكاء الاصطناعي وعشان ده اذكي تمام وما بيشربش سجاير المكتب اديك محتاج ولايس وسط الناس الخبره عمرها تيجي المكنه كمبيوتر الخبره الحقيقيه بتيجي الانسان صانع الكمبيوتر فيش احسن الذكاء الطبيعي الرضاع الطبيعي عسل جبل النحل الطبيعي الاصلي الجميل ارجوك عم بسيوني راجل طيب شوف لنا حل وشغل لنا المكنه بسم الله الرحمن الرحيم خد بالك الخبره حاضر خذ الخلاصه انجز خد الزبده بتاعت الموضوع خذ الزيتونه ماشي بكل الخضار عايزه خطوه

# %% [markdown]
# ## Remove Spaces in filenames

# %%
data["filenames"] = [name.strip() for name in data["filenames"]]
data["content"] = [content.strip() for content in data["content"]]
data["annotation"] = [ann.strip() if isinstance(ann, str) else ann for ann in data["annotation"]]

# %%
print(repr(data["filenames"][:8]))
# Out:
# ['Chat GPT  الدحيح', 'Oppenheimer  الدحيح', 'آخر يوم في العالم  الدحيح', 'أحلى برجر في العالم  الدحيح', 'أحمد عدوية  الدحيح', 'أخطر رجل مافيا  الدحيح', 'أخطر من النووي  الدحيح', 'أشهر ملاهي في كوكب الارض  الدحيح']

# %% [markdown]
# ## Remove "الدحيح" at the end of each filename

# %%
# Remove "الدحيح" if it appears at the end of filenames
data["filenames"] = [name.strip().replace(" الدحيح", "").strip() for name in data["filenames"]]

# %%
print(repr(data["filenames"][:8]))
# Out:
# ['Chat GPT', 'Oppenheimer', 'آخر يوم في العالم', 'أحلى برجر في العالم', 'أحمد عدوية', 'أخطر رجل مافيا', 'أخطر من النووي', 'أشهر ملاهي في كوكب الارض']

# %% [markdown]
# ## Analysis on the Meta Data

# %%
def create_dataframe(data):
    # creating a dataframe
    df = pd.DataFrame({
        "filename": data["filenames"],
        "content": data["content"],
        "likes": [ann["Number_of_Likes"] for ann in data["annotation"]],
        "dislikes": [ann["Number_of_Dislikes"] for ann in data["annotation"]],
        "views": [ann["Number_of_Views"] for ann in data["annotation"]],
        "comments": [ann["Number_of_Comments"] for ann in data["annotation"]],
        "categories": [ann["Categories"] for ann in data["annotation"]]
    })

    return df

# %%
df = create_dataframe(data)
df.head()
# Out:
#               filename                                            content  \
# 0             Chat GPT  عمي بسيوني الايام راجل طيب دلوقتي افتكرت عم بس...
# 1          Oppenheimer  طبعا جون مستغرب خاظفينك ليه لا والله كتر خيركم...
# 2    آخر يوم في العالم  انتم عارفين جماعه بقالنا 13 يوم محبوسين الغواص...
# 3  أحلى برجر في العالم  ايوه ماما واحشاني ست الكل والله الغربه صعبه جد...
# 4           أحمد عدوية  راح فين فندم شايفني بدور لقينا مارادونا فندم ا...
#
#     likes  dislikes    views  comments  \
# 0  158194         0  4196934      3417
# 1  206192         0  6313109      3213
# 2  156239         0  6396147      3185
# 3   98494         0  2322834      2258
# 4   54754         0  1696731      1961
#
#                                           categories
# 0  [chat gpt, how to use chat gpt, chat gpt expla...
# 1  [مشروع مانهاتن, مشروع مانهاتن النووي, manhatta...
# 2  [الدحيح, برنامج الدحيح الجديد, eldahih, elda7e...
# 3  [الدحيح, برنامج الدحيح الجديد, #daheeh #الدحيح...
# 4  [الدحيح, برنامج الدحيح الجديد, حلقة الدحيح, بر...

# %%
# Configure matplotlib to support Arabic rendering
#matplotlib.rcParams['font.family'] = 'sans-serif'
#matplotlib.rcParams['font.sans-serif'] = ['Amiri']
#matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## Method to structure arabic text correctly

# %%
# Reshape and reorder Arabic text method
def process_arabic_text(text):
    # Reshape the Arabic text
    reshaped_text = arabic_reshaper.reshape(text)
    # Apply bidirectional algorithm to correct text direction
    return get_display(reshaped_text)

# %% [markdown]
# ## Checking the most liked episode

# %%
# Sort and select top 30 episodes
top_30_liked = df.sort_values('likes', ascending=False).head(30)

# Process Arabic text in the filename column
top_30_liked['processed_filename'] = top_30_liked['filename'].apply(process_arabic_text)

# Create the plot
plt.figure(figsize=(15, 10))

# Create horizontal bar plot of top 30
ax = sns.barplot(x='likes', y='processed_filename', data=top_30_liked, palette="magma")

# Format x-axis to show whole numbers
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: f'{int(x):,}'))

# Customize ticks and labels
plt.xlabel("Likes", fontsize=12)
plt.ylabel("Filename", fontsize=12)
plt.title("Top 30 Liked Episodes", fontsize=14)

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-37-376b5a34d49b>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='likes', y='processed_filename', data=top_30_liked, palette="magma")

# %% [markdown]
# ## Checking the episode with highest comments

# %%
# Sort and select top 30 episodes based on comments
top_30_commented = df.sort_values('comments', ascending=False).head(30)

# Process Arabic text in the filename column
top_30_commented['processed_filename'] = top_30_commented['filename'].apply(process_arabic_text)

# Create the plot
plt.figure(figsize=(15, 10))

# Create horizontal bar plot of top 30 based on comments
ax = sns.barplot(x='comments', y='processed_filename', data=top_30_commented, palette="magma")

# Format x-axis to show whole numbers
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: f'{int(x):,}'))

# Customize ticks and labels
plt.xlabel("Number of Comments", fontsize=12)
plt.ylabel("Episode", fontsize=12)
plt.title("Top 30 Most Commented Episodes", fontsize=14)

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-38-1a1a43009a52>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='comments', y='processed_filename', data=top_30_commented, palette="magma")

# %% [markdown]
# ## Checking the most occurring words

# %%
# Combine all text from the content column
all_text = ' '.join(df['content'])

# Create WordCloud with Arabic font support
wordcloud = WordCloud(
    width=1600,
    height=800,
    background_color='white',
    font_path='/content/Amiri-Regular.ttf',  # Path to Amiri font
    max_words=200,
    font_step=2,
    prefer_horizontal=0.6,
    min_font_size=10
).generate(all_text)

# Display the word cloud
plt.figure(figsize=(20,10), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## Checking the most occuring categories

# %% [markdown]
# Based on the chart, the categories annotation is not imporant, it doesn't represent real categories. even if we dropped "el dahih" category, they're still very random and unuseful

# %%
def plot_top_categories(df, column, top_n=40):
    if column not in df.columns:
        print(f"Error: Column '{column}' not found in DataFrame.")
        return

    # Ensure all values are lists before exploding
    df[column] = df[column].apply(lambda x: x if isinstance(x, list) else [x])

    # Flatten lists into individual rows
    top_categories = df[column].explode().value_counts().head(top_n)

    processed_labels = [process_arabic_text(cat) for cat in top_categories.index]


    # Plot the bar chart
    plt.figure(figsize=(12, 6))
    sns.barplot(x=top_categories.values, y=processed_labels, palette="viridis")
    plt.xlabel("Count")
    plt.ylabel("Category")
    plt.title(f"Top {top_n} Most Occurring Categories")
    plt.show()

# %%
plot_top_categories(df, "categories", top_n=40)
# Out:
# <ipython-input-40-7ba7e7ce9f31>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.values, y=processed_labels, palette="viridis")

# %% [markdown]
# ## TFIDF

# %%
def compute_tfidf(df, text_column, max_features=1000):
    # Convert the text column to a list of documents
    documents = df[text_column].astype(str).tolist()

    # Initialize TF-IDF Vectorizer
    vectorizer = TfidfVectorizer(max_features=max_features)

    # Fit and transform the text data
    tfidf_matrix = vectorizer.fit_transform(documents)

    # Convert the result to a DataFrame
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

    return tfidf_df

# %%
tfidf_result = compute_tfidf(df, "content")
print(tfidf_result.head())
# Out:
#          10       100        12        15        20        30        40  \
# 0  0.020988  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.008331  0.027475  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.009607  0.010561  0.013333  0.012116  0.032207  0.011387  0.000000
# 3  0.006058  0.000000  0.000000  0.000000  0.013539  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.005291  0.004688  0.000000  0.005822
#
#          50       and        in  ...    يقولك       يكن       يلا      يمكن  \
# 0  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.009592  0.000000
# 1  0.000000  0.028075  0.014834  ...  0.00000  0.000000  0.007615  0.021098
# 2  0.000000  0.016188  0.000000  ...  0.02614  0.011486  0.026344  0.024330
# 3  0.007711  0.030623  0.000000  ...  0.00000  0.000000  0.000000  0.005114
# 4  0.000000  0.000000  0.000000  ...  0.00000  0.010032  0.000000  0.021249
#
#        يموت     ينفعش     يوصل       يوم  يونايتد      ييجي
# 0  0.000000  0.024248  0.00000  0.008027      0.0  0.000000
# 1  0.000000  0.028875  0.00979  0.006373      0.0  0.000000
# 2  0.000000  0.000000  0.00000  0.110239      0.0  0.011689
# 3  0.016987  0.000000  0.00000  0.004634      0.0  0.000000
# 4  0.000000  0.004847  0.00000  0.032093      0.0  0.000000
#
# [5 rows x 1000 columns]

# %%
print(list(tfidf_result.columns))
# Out:
# ['10', '100', '12', '15', '20', '30', '40', '50', 'and', 'in', 'marvel', 'of', 'that', 'the', 'to', 'you', 'ابدا', 'ابقي', 'ابل', 'ابن', 'ابني', 'ابو', 'ابوه', 'ابيض', 'اتنين', 'اثناء', 'احد', 'احسن', 'احمد', 'احنا', 'احيانا', 'اختراع', 'اخر', 'اخوه', 'اخيرا', 'اد', 'اديسون', 'اذا', 'ارجوك', 'ارض', 'ازاي', 'استاذ', 'استخدام', 'استني', 'اسطي', 'اسم', 'اسمه', 'اسمها', 'اسود', 'اسيا', 'اشهر', 'اصلا', 'اعرف', 'اعزايي', 'اعلي', 'اعمل', 'اغلب', 'افريقيا', 'افضل', 'اقل', 'اقول', 'اقولك', 'اقوي', 'اكبر', 'اكتر', 'اكثر', 'اكل', 'اكيد', 'الا', 'الاب', 'الاتحاد', 'الاتنين', 'الاخر', 'الارض', 'الاشعاع', 'الاطفال', 'الاف', 'الاقل', 'الاكسجين', 'الاكل', 'الالمان', 'الالماني', 'الام', 'الامريكان', 'الامريكي', 'الامريكيه', 'الانتخابات', 'الانجليز', 'الانجليزي', 'الانسان', 'الاول', 'الاولي', 'الباحثين', 'البحر', 'البرنامج', 'البريطاني', 'البشر', 'البشريه', 'البطاطس', 'البكتيريا', 'البلد', 'البيت', 'البييه', 'التاريخ', 'التاني', 'التانيه', 'التجربه', 'التشريح', 'التوحد', 'التيار', 'الثوره', 'الجايه', 'الجثث', 'الجديد', 'الجديده', 'الجزء', 'الجسم', 'الجمال', 'الجمل', 'الجمهور', 'الجميل', 'الجنود', 'الجيش', 'الحاجات', 'الحاجه', 'الحاله', 'الحراره', 'الحرب', 'الحركه', 'الحزب', 'الحقيقه', 'الحقيقي', 'الحكم', 'الحكومه', 'الحلقات', 'الحلقه', 'الحلم', 'الحمد', 'الحمله', 'الحياه', 'الحيوان', 'الحيوانات', 'الخوف', 'الدحيح', 'الدراسات', 'الدكتور', 'الدم', 'الدنيا', 'الدول', 'الدوله', 'الدين', 'الذكاء', 'الراجل', 'الرحله', 'الرييس', 'الساعه', 'السبب', 'الستات', 'السجن', 'السفينه', 'السلام', 'السلطان', 'السنه', 'السنين', 'السوال', 'السوفييتي', 'السوق', 'الشارع', 'الشباب', 'الشخص', 'الشخصيه', 'الشرق', 'الشركات', 'الشركه', 'الشعب', 'الشغل', 'الشكل', 'الشمس', 'الصغير', 'الصوره', 'الصين', 'الصيني', 'الصينيه', 'الطاقه', 'الطب', 'الطبيعه', 'الطريق', 'الطريقه', 'الطفل', 'الطياره', 'العادي', 'العالم', 'العالميه', 'العرب', 'العربيه', 'العصر', 'العظيم', 'العلاج', 'العلم', 'العلماء', 'الـماتش', 'الـيوتيوب', 'الف', 'الفتره', 'الفرق', 'الفرنسي', 'الفرنسيه', 'الفرنسيين', 'الفريق', 'الفضاء', 'الفكره', 'الفلوس', 'الفول', 'الفيل', 'الفيلم', 'القادر', 'القانون', 'القاهره', 'القديم', 'القديمه', 'القرن', 'القصه', 'القناه', 'القنبله', 'القوه', 'الكابون', 'الكاتب', 'الكبير', 'الكبيره', 'الكتاب', 'الكل', 'الكلام', 'الكهربا', 'الكوره', 'الكوكب', 'اللبن', 'اللحظه', 'اللحمه', 'اللعبه', 'اللغه', 'الله', 'اللوحه', 'الماسونيه', 'المانيا', 'المبني', 'المتحده', 'المجتمع', 'المخ', 'المدرسه', 'المدينه', 'المرادي', 'المرض', 'المستقبل', 'المشاهد', 'المشاهدين', 'المشكله', 'المصادر', 'المعركه', 'المعلومات', 'المفروض', 'المكان', 'الملح', 'الملك', 'المماليك', 'المنطقه', 'المهم', 'الموت', 'الموضوع', 'الميه', 'الناحيه', 'النادي', 'الناس', 'النباتات', 'النبي', 'النظام', 'النفس', 'النفسي', 'النفسيه', 'النمر', 'النمور', 'النهارده', 'النهايه', 'النوع', 'النووي', 'الهند', 'الواد', 'الواقع', 'الوحيد', 'الوحيده', 'الوضع', 'الوقت', 'الولايات', 'الي', 'اليابان', 'اليهود', 'اليوم', 'ام', 'اما', 'امال', 'امتي', 'امريكا', 'امه', 'ان', 'انا', 'انت', 'انتاج', 'انتم', 'انتي', 'انجلترا', 'انسان', 'انك', 'انما', 'اننا', 'انه', 'انها', 'انهم', 'انواع', 'اني', 'اه', 'اهلا', 'اهم', 'اهو', 'اوروبا', 'اول', 'اولا', 'اوي', 'اي', 'ايام', 'ايد', 'ايده', 'ايرلندا', 'ايضا', 'ايه', 'ايوه', 'بابا', 'باسم', 'بالرغم', 'بالظبط', 'بالفعل', 'بالك', 'بالكامل', 'بالنسبه', 'باي', 'ببساطه', 'بتاع', 'بتاعت', 'بتاعتنا', 'بتاعته', 'بتاعك', 'بتاعنا', 'بتاعه', 'بتاعها', 'بتبدا', 'بتبقي', 'بتتكلم', 'بتحصل', 'بتطلع', 'بتظهر', 'بتعمل', 'بتقول', 'بتكون', 'بجد', 'بحيث', 'بدا', 'بدات', 'بدايه', 'بدل', 'بدون', 'برضه', 'برنامج', 'بره', 'بريطانيا', 'بس', 'بسبب', 'بسرعه', 'بسيط', 'بسيطه', 'بشكل', 'بص', 'بصراحه', 'بطل', 'بعد', 'بعدها', 'بعض', 'بعيد', 'بقت', 'بقي', 'بكتير', 'بكل', 'بكم', 'بل', 'بلا', 'بلد', 'بن', 'بنتكلم', 'بنشوف', 'بنفس', 'بنفسه', 'بني', 'بهذا', 'بهذه', 'بيبدا', 'بيبقي', 'بيت', 'بيتم', 'بيتهوفن', 'بيحاول', 'بيحصل', 'بيخلي', 'بيطلع', 'بيظهر', 'بيعمل', 'بيعملوا', 'بيقول', 'بيكون', 'بيلعب', 'بيموت', 'بين', 'بينما', 'بينهم', 'بيه', 'بيها', 'بيوصل', 'بييجي', 'تاثير', 'تاخد', 'تاريخ', 'تاني', 'تانيه', 'تايتانيك', 'تايسون', 'تبدا', 'تبص',  ...

# %%
print((tfidf_result["in"]))
# Out:
# 0      0.000000
# 1      0.014834
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 140    0.000000
# 141    0.000000
# 142    0.000000
# 143    0.000000
# 144    0.000000
# Name: in, Length: 145, dtype: float64

# %%
def plot_tfidf_word(tfidf_df, word):
    if word not in tfidf_df.columns:
        print(f"'{word}' not found in the TF-IDF results.")
        return

    # Extract the TF-IDF scores for the word
    word_scores = tfidf_df[word]

    # Plot the values
    plt.figure(figsize=(12, 6))
    sns.barplot(x=word_scores.index, y=word_scores.values, palette="viridis")

    # Label the chart
    plt.xlabel("Document Index")
    plt.ylabel("TF-IDF Score")
    plt.title(f"TF-IDF Scores for the word: '{word}'")

    # Show the plot
    plt.show()

# %%
plot_tfidf_word(tfidf_result, "عزيزي")
# Out:
# <ipython-input-46-8f8f21cb02a4>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=word_scores.index, y=word_scores.values, palette="viridis")

# %%
sns.regplot(data=df, x="views", y="comments", scatter_kws={"alpha":0.5})
plt.xlabel("Views")
plt.ylabel("Number of Comments")
plt.title("Views vs. Comments Correlation")
plt.show()
